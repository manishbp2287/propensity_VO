# %%
import altair as alt
import numpy as np
import pandas as pd
import pandas_gbq
import os.path
import seaborn as sns
import category_encoders as ce
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
alt.data_transformers.enable('default', max_rows=None)
pd.options.display.max_columns = None

# %%
# Speaker order date starts from 2022-03
product = "speaker" # Comment out the app data (read and merge) for Speaker

# %%
# push_merchants_in_application = pd.read_csv(f"{product}_push_merchants_in_application.csv")
tot_push_merchants = pd.read_csv(f'{product}_total_push_merchants.csv')
tot_app_merchants = pd.read_csv(f'{product}_total_application_merchants.csv')
vint = pd.read_csv(f'{product}_vin.csv')

# %%
vin_dic = vint.set_index('merchant_id')['vintage'].to_dict()

# %%
print(f"There are a total of {tot_push_merchants.shape[0]} merchants in Push (lmp)")
# Out:
# There are a total of 866248 merchants in Push (lmp)

# %%
# print(f"There are {push_merchants_in_application.shape[0]} merchants which moved to Application within 7 days of Push (lmp)")

# %%
print(f"There are a total of {tot_app_merchants.shape[0]} merchants in Application")
# Out:
# There are a total of 507369 merchants in Application

# %%
pdt_final = pd.DataFrame()
pdt_final['merchant_id'] = list(set(list(tot_app_merchants['merchant_id']) + list(tot_push_merchants['merchant_id'])))

# %%
print(f"There are a total of {pdt_final.shape[0]} distinct merchants in the union of Application and push tables")
# Out:
# There are a total of 961420 distinct merchants in the union of Application and push tables

# %%
# c1 = pdt_final['merchant_id'].isin(push_merchants_in_application['merchant_id'])
c2 = (pdt_final['merchant_id'].isin(tot_app_merchants['merchant_id'])) & (~pdt_final['merchant_id'].isin(tot_push_merchants['merchant_id']))
c3 = pdt_final['merchant_id'].isin(tot_app_merchants['merchant_id'])

# c = c1 | c2
pdt_final['target'] = np.where(c3, 1, 0)

# %%
# print(f"There are a total of {sum(c2)} merchants that were never in the Push but in the Application")

# %%
pdt_final['target'].value_counts()
# Out:
# 1    507369
# 0    454051
# Name: target, dtype: int64

# %%
trxn_pdt = pd.read_csv(f"trxn_{product}.csv")
merchant_data_mart = pd.read_csv(f"{product}_merchant_data_mart.csv",low_memory=False)
app_pdt = pd.read_csv(f'app_{product}.csv') # Comment this out for speaker

# %%
pdt_flag = f'{product}_flag'
pdt_order_date = f'{product}_order_date'

# %%
rel_cols = ['merchant_id', 'actual_merchant_type','area_name','zone_name','region_name','territory_name',\
                            'business_category','merchant_acquisition_channel',\
                            pdt_order_date,'merchant_created_at','geohash6','geohash3', 'geohash4']
if product in ['loan','fp']: 
    rel_cols = ['merchant_id', 'actual_merchant_type','area_name','zone_name','region_name','territory_name',\
                            'business_category','merchant_acquisition_channel','merchant_created_at','geohash6','geohash3', 'geohash4']



pdt = merchant_data_mart[rel_cols]

# %%
device = """
SELECT * FROM `bharatpe-analytics-prod.bharatpe_ml_data.merchant_device_info`
"""
device = pandas_gbq.read_gbq(device)
# Out:
# Downloading: 100%|██████████| 9236615/9236615 [04:28<00:00, 34404.72rows/s]

# %%
device = device[device['merchant_id'].isin(pdt_final['merchant_id'])]

# %%
pdt_final = pdt_final.merge(device[['merchant_id','manufacturer']], how = 'left', left_on = "merchant_id", right_on = "merchant_id")

# %%
del(device)

# %%
pdt_final['manufacturer'].fillna('Other', inplace = True)
# pdt_final['version'].fillna('Other', inplace = True)

# %%
pdt_final = pdt_final.merge(pdt, how = 'left', left_on = "merchant_id", right_on = "merchant_id")

# %%
pdt_final = pdt_final.merge(trxn_pdt, how = 'left', left_on = "merchant_id", right_on = "merchant_id")

# %%
# Comment this for speaker
pdt_final = pdt_final.merge(app_pdt, how = 'left', left_on = "merchant_id", right_on = "merchant_id")

# %%
c1 = pdt_final['w1_txn_count'] - pdt_final['w2_txn_count']
c2 = pdt_final['w2_txn_count'] - pdt_final['w3_txn_count']
pdt_final['trend'] = np.where((c1>0) & (c2>0), "up",np.where((c1<0) & (c2<0),"down","flat"))

# %%
pdt_final['vintage'] = pdt_final['merchant_id'].map(vin_dic)

# %%
pdt_final['manufacturer'] = pdt_final['manufacturer'].str.lower()
pdt_final['manufacturer'] = pdt_final['manufacturer'].replace({'tecno mobile limited': 'tecno', 'infinix mobility limited': 'infinix', 'hmd global': 'hmd'\
                                   , 'itel mobile limited': 'itel'})

major_brands = list(pdt_final['manufacturer'].str.lower().value_counts()[:20].index)

pdt_final['manufacturer'] = np.where(pdt_final['manufacturer'].isin(major_brands),pdt_final['manufacturer'], 'other')
# pdt_final['version'] = pdt_final['version'].apply(lambda x :"new" if x in ('11','12') else 'old')

# %%
geo = 'geohash4'

# %%
loc_hash_density = pdt_final.groupby(geo).apply(lambda x:x['merchant_id'].nunique()).sort_values(ascending = False).to_dict()
pdt_final['loc_hash_density'] = pdt_final[geo].map(loc_hash_density)

# %%
loc_hash_atv = pdt_final.groupby(geo).apply(lambda x:x['total_tpv'].sum()/ len(x)).sort_values(ascending = False).to_dict()
pdt_final['loc_hash_atv'] = pdt_final[geo].map(loc_hash_atv)

# %%
loc_hash_tpv = pdt_final.groupby(geo).apply(lambda x:x['total_tpv'].sum()).sort_values(ascending = False).to_dict()
pdt_final['loc_hash_tpv'] = pdt_final[geo].map(loc_hash_tpv)

# %%
##### Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from xgboost import XGBClassifier, plot_importance
from sklearn.metrics import plot_confusion_matrix

# %%
# sum(pdt_final['txn_count_90_days'].isna())

# %%
pdt_final = pdt_final[~pdt_final['txn_count_90_days'].isna()]

# %%
pdt_final['target'].value_counts()
# Out:
# 1    506979
# 0    445834
# Name: target, dtype: int64

# %%
if product == 'fp':
    pdt_final = pd.concat([pdt_final[pdt_final['target']==0].sample(pdt_final['target'].value_counts().min()), pdt_final[pdt_final['target']==1]], axis=0)
# pdt_final = pd.concat([pdt_final[pdt_final['target']==1].sample(pdt_final['target'].value_counts().min()), pdt_final[pdt_final['target']==0]], axis=0)

# %%
pdt_final['target'].value_counts()
# Out:
# 1    506979
# 0    445834
# Name: target, dtype: int64

# %%
pdt_final['m1_atv'] = pdt_final['m1_tpv']/pdt_final['m1_txn_count']
pdt_final['m2_atv'] = pdt_final['m2_tpv']/pdt_final['m2_txn_count']
pdt_final['total_atv'] = pdt_final['total_tpv']/pdt_final['total_txn_count']
pdt_final['txn_activeday'] = pdt_final['total_txn_count']/pdt_final['total_active_vintage']
pdt_final['m1_txn_activeday'] = pdt_final['m1_txn_count']/pdt_final['m1_active_days']
pdt_final['m2_txn_activeday'] = pdt_final['m2_txn_count']/pdt_final['m2_active_days']
# pdt_final['m3_txn_activeday'] = pdt_final['m3_txn_count']/pdt_final['m3_active_days']
pdt_final['m1_max_daily_by_tpv'] = pdt_final['m1_max_daily_tpv']/pdt_final['m1_tpv']
# pdt_final['m2_max_daily_by_tpv'] = pdt_final['m2_max_daily_tpv']/pdt_final['m2_tpv']
# pdt_final['m3_max_daily_by_tpv'] = pdt_final['m3_max_daily_tpv']/pdt_final['m3_tpv']
pdt_final['m1_max_daily_by_payees'] = pdt_final['m1_max_daily_payees']/pdt_final['m1_unique_payers']
pdt_final['m1_max_daily_by_txns'] = pdt_final['m1_max_daily_txns']/pdt_final['m1_txn_count']

# %%
# ONE_HOT_COLS = ['zone_name', 'business_category', 'trend','actual_merchant_type']
# ONE_HOT_COLS = ['zone_name', 'business_category', 'trend','geohash6', 'geohash3', 'geohash4']
# ONE_HOT_COLS = ['zone_name', 'business_category', 'trend','geohash3']
ONE_HOT_COLS = ['zone_name', 'business_category', 'trend',geo,'manufacturer']

# %%
nan_ind = list(pdt_final[pdt_final[ONE_HOT_COLS].isnull().any(axis=1) == 1].index)
pdt_final = pdt_final[~pdt_final.index.isin(nan_ind)]
# pdt_final = pdt_final[~pdt_final.index.isin(nan_ind)].reset_index(drop = True)

# %%
num_cols = list(pdt_final.columns[pdt_final.dtypes!=np.object][2:])
cat_cols = pdt_final.columns[pdt_final.dtypes==np.object]
# len(num_cols)

# %%
# pdt_final[pdt_final['vintage']<0]['vintage'] = 0
pdt_final.loc[pdt_final['vintage']<0,'vintage']=0

# %%
for c in ONE_HOT_COLS:
    pdt_final[c] = pdt_final[c].astype("category")

# %%
# pdt_final = pdt_final.fillna(0)
y = pdt_final['target']
X = pdt_final[num_cols + ONE_HOT_COLS] #pdt_final[imp_num], num_cols

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y ,test_size=0.25,stratify=y,shuffle = True)

# %%
# clf = RandomForestClassifier(random_state=0)
# clf.fit(X_train, y_train)
# Ref: https://xgboost.readthedocs.io/en/stable/tutorials/categorical.html
params={'n_estimators':150,'colsample_bytree': 0.8, 'gamma': 1.5, 'learning_rate': 0.1, 'max_depth': 6 ,'subsample': 1.0}
clf = XGBClassifier(objective="binary:logistic", eval_metric=["auc","error"], use_label_encoder=False, random_state = 0, enable_categorical=True,\
                    tree_method="approx")
clf.set_params(**params)
eval_set = [(X_test, y_test)]
clf.fit(X_train, y_train,eval_set=eval_set,verbose=True)
# clf.save_model("categorical-model.json")
# Out:
# [0]	validation_0-auc:0.75537	validation_0-error:0.30291
# [1]	validation_0-auc:0.77258	validation_0-error:0.29399
# [2]	validation_0-auc:0.77625	validation_0-error:0.28900
# [3]	validation_0-auc:0.77809	validation_0-error:0.28792
# [5]	validation_0-auc:0.78075	validation_0-error:0.28538
# [6]	validation_0-auc:0.78119	validation_0-error:0.28471
# [7]	validation_0-auc:0.78178	validation_0-error:0.28423
# [8]	validation_0-auc:0.78204	validation_0-error:0.28408
# [9]	validation_0-auc:0.78240	validation_0-error:0.28372
# [10]	validation_0-auc:0.78275	validation_0-error:0.28352
# [11]	validation_0-auc:0.78308	validation_0-error:0.28314
# [12]	validation_0-auc:0.78348	validation_0-error:0.28281
# [13]	validation_0-auc:0.78381	validation_0-error:0.28276
# [14]	validation_0-auc:0.78504	validation_0-error:0.28172
# [15]	validation_0-auc:0.78564	validation_0-error:0.28106
# [16]	validation_0-auc:0.78609	validation_0-error:0.28052
# [17]	validation_0-auc:0.78652	validation_0-error:0.28008
# [18]	validation_0-auc:0.78719	validation_0-error:0.27973
# [19]	validation_0-auc:0.78754	validation_0-error:0.27956
# [20]	validation_0-auc:0.78804	validation_0-error:0.27938
# [21]	validation_0-auc:0.78827	validation_0-error:0.27917
# [22]	validation_0-auc:0.78864	validation_0-error:0.27902
# [23]	validation_0-auc:0.78898	validation_0-error:0.27868
# [24]	validation_0-auc:0.78958	validation_0-error:0.27838
# [25]	validation_0-auc:0.78980	validation_0-error:0.27805
# [26]	validation_0-auc:0.79013	validation_0-error:0.27788
# [27]	validation_0-auc:0.79036	validation_0-error:0.27773
# [28]	validation_0-auc:0.79050	validation_0-error:0.27753
# [29]	validation_0-auc:0.79067	validation_0-error:0.27762
# [30]	validation_0-auc:0.79087	validation_0-error:0.27760
# [31]	validation_0-auc:0.79104	validation_0-error:0.27760
# [32]	validation_0-auc:0.79152	validation_0-error:0.27702
# [33]	validation_0-auc:0.79168	validation_0-error:0.27701
# [34]	validation_0-auc:0.79217	validation_0-error:0.27660
# [35]	validation_0-auc:0.79268	validation_0-error:0.27615
# [36]	validation_0-auc:0.79273	validation_0-error:0.27602
# [37]	validation_0-auc:0.79313	validation_0-error:0.27573
# [38]	validation_0-auc:0.79318	validation_0-error:0.27577
# [39]	validation_0-auc:0.79330	validation_0-error:0.27553
# [40]	validation_0-auc:0.79347	validation_0-error:0.27544
# [41]	validation_0-auc:0.79369	validation_0-error:0.27542
# [42]	validation_0-auc:0.79395	validation_0-error:0.27536
# [43]	validation_0-auc:0.79396	validation_0-error:0.27538
# [44]	validation_0-auc:0.79413	validation_0-error:0.27524
# [45]	validation_0-auc:0.79424	validation_0-error:0.27515
# [46]	validation_0-auc:0.79431	validation_0-error:0.27513
# [47]	validation_0-auc:0.79436	validation_0-error:0.27502
# [48]	validation_0-auc:0.79442	validation_0-error:0.27498
# [49]	validation_0-auc:0.79441	validation_0-error:0.27491
# [50]	validation_0-auc:0.79463	validation_0-error:0.27474
# [51]	validation_0-auc:0.79493	validation_0-error:0.27449
# [52]	validation_0-auc:0.79498	validation_0-error:0.27446
# [53]	validation_0-auc:0.79509	validation_0-error:0.27456
# [54]	validation_0-auc:0.79512	validation_0-error:0.27448
# [55]	validation_0-auc:0.79524	validation_0-error:0.27444
# [56]	validation_0-auc:0.79543	validation_0-error:0.27423
# [57]	validation_0-auc:0.79552	validation_0-error:0.27418
# [58]	validation_0-auc:0.79551	validation_0-error:0.27437
# [59]	validation_0-auc:0.79557	validation_0-error:0.27414
# [60]	validation_0-auc:0.79555	validation_0-error:0.27421
# [61]	validation_0-auc:0.79559	validation_0-error:0.27436
# [62]	validation_0-auc:0.79560	validation_0-error:0.27425
# [63]	validation_0-auc:0.79571	validation_0-error:0.27428
# [64]	validation_0-auc:0.79576	validation_0-error:0.27412
# [65]	validation_0-auc:0.79593	validation_0-error:0.27400
# [66]	validation_0-auc:0.79594	validation_0-error:0.27398
# [67]	validation_0-auc:0.79613	validation_0-error:0.27389
# [68]	validation_0-auc:0.79623	validation_0-error:0.27386
# [69]	validation_0-auc:0.79628	validation_0-error:0.27389
# [70]	validation_0-auc:0.79636	validation_0-error:0.27376
# [71]	validation_0-auc:0.79644	validation_0-error:0.27373
# [72]	validation_0-auc:0.79642	validation_0-error:0.27395
# [73]	validation_0-auc:0.79645	validation_0-error:0.27389
# [74]	validation_0-auc:0.79642	validation_0-error:0.27373
# [75]	validation_0-auc:0.79644	validation_0-error:0.27371
# [76]	validation_0-auc:0.79656	validation_0-error:0.27360
# [77]	validation_0-auc:0.79668	validation_0-error:0.27350
# [78]	validation_0-auc:0.79669	validation_0-error:0.27357
# [80]	validation_0-auc:0.79678	validation_0-error:0.27348
# [81]	validation_0-auc:0.79678	validation_0-error:0.27357
# [82]	validation_0-auc:0.79684	validation_0-error:0.27353
# [83]	validation_0-auc:0.79688	validation_0-error:0.27343
# [84]	validation_0-auc:0.79705	validation_0-error:0.27323
# [85]	validation_0-auc:0.79708	validation_0-error:0.27325
# [86]	validation_0-auc:0.79705	validation_0-error:0.27331
# [87]	validation_0-auc:0.79716	validation_0-error:0.27321
# [88]	validation_0-auc:0.79722	validation_0-error:0.27317
# [89]	validation_0-auc:0.79722	validation_0-error:0.27307
# [90]	validation_0-auc:0.79718	validation_0-error:0.27314
# [91]	validation_0-auc:0.79721	validation_0-error:0.27314
# [92]	validation_0-auc:0.79725	validation_0-error:0.27314
# [93]	validation_0-auc:0.79729	validation_0-error:0.27309
# [94]	validation_0-auc:0.79734	validation_0-error:0.27298
# [95]	validation_0-auc:0.79745	validation_0-error:0.27298
# [96]	validation_0-auc:0.79747	validation_0-error:0.27308
# [97]	validation_0-auc:0.79745	validation_0-error:0.27309
# [98]	validation_0-auc:0.79748	validation_0-error:0.27298
# [99]	validation_0-auc:0.79751	validation_0-error:0.27304
# [100]	validation_0-auc:0.79749	validation_0-error:0.27292
# [101]	validation_0-auc:0.79753	validation_0-error:0.27295
# [102]	validation_0-auc:0.79762	validation_0-error:0.27277
# [103]	validation_0-auc:0.79763	validation_0-error:0.27279
# [104]	validation_0-auc:0.79765	validation_0-error:0.27278
# [105]	validation_0-auc:0.79770	validation_0-error:0.27276
# [106]	validation_0-auc:0.79769	validation_0-error:0.27274
# [107]	validation_0-auc:0.79771	validation_0-error:0.27271
# [108]	validation_0-auc:0.79782	validation_0-error:0.27270
# [109]	validation_0-auc:0.79784	validation_0-error:0.27254
# [110]	validation_0-auc:0.79794	validation_0-error:0.27249
# [111]	validation_0-auc:0.79795	validation_0-error:0.27251
# [112]	validation_0-auc:0.79800	validation_0-error:0.27225
# [113]	validation_0-auc:0.79801	validation_0-error:0.27224
# [114]	validation_0-auc:0.79803	validation_0-error:0.27223
# [115]	validation_0-auc:0.79806	validation_0-error:0.27219
# [116]	validation_0-auc:0.79808	validation_0-error:0.27218
# [117]	validation_0-auc:0.79808	validation_0-error:0.27228
# [118]	validation_0-auc:0.79809	validation_0-error:0.27234
# [119]	validation_0-auc:0.79811	validation_0-error:0.27235
# [120]	validation_0-auc:0.79813	validation_0-error:0.27237
# [121]	validation_0-auc:0.79819	validation_0-error:0.27224
# [122]	validation_0-auc:0.79819	validation_0-error:0.27227
# [123]	validation_0-auc:0.79820	validation_0-error:0.27224
# [124]	validation_0-auc:0.79828	validation_0-error:0.27209
# [125]	validation_0-auc:0.79832	validation_0-error:0.27207
# [126]	validation_0-auc:0.79830	validation_0-error:0.27217
# [127]	validation_0-auc:0.79831	validation_0-error:0.27217
# [128]	validation_0-auc:0.79832	validation_0-error:0.27215
# [129]	validation_0-auc:0.79828	validation_0-error:0.27217
# [130]	validation_0-auc:0.79836	validation_0-error:0.27210
# [131]	validation_0-auc:0.79836	validation_0-error:0.27193
# [132]	validation_0-auc:0.79838	validation_0-error:0.27197
# [133]	validation_0-auc:0.79843	validation_0-error:0.27208
# [134]	validation_0-auc:0.79843	validation_0-error:0.27197
# [135]	validation_0-auc:0.79849	validation_0-error:0.27198
# [136]	validation_0-auc:0.79850	validation_0-error:0.27181
# [137]	validation_0-auc:0.79853	validation_0-error:0.27181
# [138]	validation_0-auc:0.79852	validation_0-error:0.27177
# [139]	validation_0-auc:0.79856	validation_0-error:0.27176
# [140]	validation_0-auc:0.79865	validation_0-error:0.27175
# [141]	validation_0-auc:0.79862	validation_0-error:0.27170
# [142]	validation_0-auc:0.79860	validation_0-error:0.27182
# [143]	validation_0-auc:0.79862	validation_0-error:0.27181
# [144]	validation_0-auc:0.79863	validation_0-error:0.27180
# [145]	validation_0-auc:0.79865	validation_0-error:0.27192
# [146]	validation_0-auc:0.79866	validation_0-error:0.27174
# [147]	validation_0-auc:0.79868	validation_0-error:0.27180
# [148]	validation_0-auc:0.79863	validation_0-error:0.27180
# [149]	validation_0-auc:0.79866	validation_0-error:0.27183
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.8,
#               early_stopping_rounds=None, enable_categorical=True,
#               eval_metric=['auc', 'error'], gamma=1.5, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_to_onehot=4, max_delta_step=0, max_depth=6, max_leaves=0,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=150, n_jobs=0, num_parallel_tree=1, predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred = clf.predict(X_test)

# %%
pickle.dump(clf, open(f"{product}_model", 'wb'))

# %%
clf = pickle.load(open(f"{product}_model", 'rb'))

# %%
roc_auc_score(y_test, clf.predict_proba(X_test)[:,1])
# Out:
# 0.7980977898333326

# %%
##### start

# %%
from sklearn.metrics import classification_report

# %%
d = {}
for thres in range(20,90,5):
    # print(thres/100)
    y_pred = 1*(clf.predict_proba(X_test)[:,1]>thres/100)
    d[thres] = pd.DataFrame([thres/100, sum(y_pred ==1),sum(y_test[y_pred==1]==1)/ sum(y_pred),\
                            sum(y_pred[y_test==1]==1)/sum(y_test==1)],index = ['threshold','predicted_positive','precision','recall']).T

# %%
res = pd.concat([d[k] for k in d.keys()], axis = 0).reset_index(drop = True)

# %%
c1 = alt.Chart(res, title = "Precision of Positive Class").mark_line(color = 'blue',).encode(
x = 'threshold:Q',
    y = alt.Y('precision:Q')
)

c2 = alt.Chart(res).mark_line(color = 'red').encode(
x = 'threshold',
    y = alt.Y('recall')
)

c3 = alt.Chart(res).mark_bar(color = 'black').encode(
x = 'threshold',
    y = alt.Y('predicted_positive:Q')
)
(c1+c2) | c3
# Out:
# alt.HConcatChart(...)

# %%
res
# Out:
#     threshold  predicted_positive  precision    recall
# 0        0.20            200144.0   0.605649  0.976729
# 1        0.25            188922.0   0.628095  0.956134
# 2        0.30            177633.0   0.650020  0.930382
# 3        0.35            166872.0   0.670514  0.901575
# 4        0.40            156582.0   0.689121  0.869457
# 5        0.45            146046.0   0.707585  0.832682
# 6        0.50            135372.0   0.724596  0.790379
# 7        0.55            124071.0   0.742615  0.742412
# 8        0.60            111580.0   0.762242  0.685315
# 9        0.65             97640.0   0.781985  0.615229
# 10       0.70             81624.0   0.802754  0.527972
# 11       0.75             63568.0   0.826406  0.423295
# 12       0.80             44885.0   0.850952  0.307764
# 13       0.85             26832.0   0.874143  0.188993

# %%
# for thresh in range(21):
for thresh in [.75]:
    # print(thresh/20)
    plt.figure(figsize=(4, 3))
    ax= plt.subplot()
    y_out = np.where(clf.predict_proba(X_test)[:,1] > thresh, 1,0)
    
    #y_test_out = np.where(y_t > 0.5, 1,0)
    cm = confusion_matrix(y_test, y_out)
    #ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    f = sns.heatmap(cm, annot=True,ax=ax)
    ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
    ax.set_title('Confusion Matrix'); 
    plt.show()
    # break
# print(classification_report(y_test,y_out))

# %%
# from xgboost import plot_tree
# import matplotlib.pyplot as plt
# # from sklearn import tree
# from matplotlib.pylab import rcParams
# plot_tree(clf)
# fig = plt.gcf()
# fig.set_size_inches(150, 100)
# fig.savefig('tree.svg')

# %%
# thres = .75
# y_pred = 1*(clf.predict_proba(X_test)[:,1]>thres)

# sum(y_pred[y_test==1]==1)/sum(y_test==1) #recall

# sum(y_test[y_pred==1]==1)/ sum(y_pred) #precision

# print(classification_report(y_test, y_pred))

# %%
##### end

# %%
plot_confusion_matrix(clf, X_test, y_test, normalize = 'true')
plt.grid(False)
plt.show()

# %%
sum(y_pred == y_test)/len(y_test)
# Out:
# 0.5524738759900021

# %%
imp_df = pd.DataFrame({
    "Varname": X_train.columns,
    "Imp": clf.feature_importances_
})
imp_df.sort_values(by="Imp", ascending=False).iloc[:20,:]
# Out:
#                  Varname       Imp
# 7           w1_txn_count  0.190823
# 16                w1_tpv  0.129626
# 14       total_txn_count  0.114988
# 6    total_unique_payers  0.044389
# 54          manufacturer  0.041132
# 40          loc_hash_tpv  0.040826
# 44         txn_activeday  0.036725
# 0       w1_unique_payers  0.030104
# 25        m3_active_days  0.024675
# 37               vintage  0.023420
# 35           w1_sessions  0.021866
# 53              geohash4  0.020412
# 18                m1_tpv  0.018444
# 32     m1_max_daily_txns  0.017906
# 23        m1_active_days  0.017844
# 36           m1_sessions  0.016684
# 17                w2_tpv  0.015645
# 43             total_atv  0.015006
# 46      m2_txn_activeday  0.014985
# 15  total_active_vintage  0.014630

# %%
plot_importance(clf, max_num_features =20,importance_type='gain')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
plot_importance(clf, max_num_features =20,importance_type='weight')
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification

preds = clf.predict_proba(X_test)[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
##### EDA

# %%
# gain_num =['total_txn_count','w1_txn_count','w1_tpv','w1_unique_payers','m1_active_days','m1_tpv','w1_sessions','total_atv','total_unique_payers','m1_atv',\
# 'total_active_vintage','m1_max_daily_tpv','m2_active_days','m1_sessions']
# gain_cat =['business_category', 'actual_merchant_type','zone_name']

# %%
vis_df = pdt_final[list(imp_df['Varname'].unique()) + ['target']]
num_cols = list(vis_df.columns[vis_df.dtypes==np.float]) 
cat_cols = list(vis_df.columns[vis_df.dtypes!=np.float])
num_df = vis_df[num_cols]
cat_df = vis_df[cat_cols]

from sklearn.preprocessing import StandardScaler, MinMaxScaler

# scaler = StandardScaler()
scaler = MinMaxScaler()
# num_df = pd.DataFrame(scaler.fit_transform(num_df), index=num_df.index, columns=num_df.columns)
num_df['target'] = pdt_final['target']
num_df['merchant_id'] = pdt_final['merchant_id']
cat_df['target'] = pdt_final['target']
cat_df['merchant_id'] = pdt_final['merchant_id']

# %%
def cat_alt(col):
    df = (100*cat_df.groupby(col)["target"].mean()).to_frame().reset_index()
    df['Count of Merchants'] = list(cat_df.groupby(col)["merchant_id"].count())
    alt.themes.enable('fivethirtyeight')
    base = alt.Chart(df).encode(x=alt.X(f'{col}:N',axis=alt.Axis(title="") ))

    bar = base.mark_bar(color = 'lightgrey').encode(y=alt.Y('target:Q',axis=alt.Axis(title="Propensity %")))

    line =  base.mark_line(color='aqua').encode(
        y='Count of Merchants:Q'
    )
    txt_bar = bar.mark_text(align='center',
            baseline='middle',
            dy=-6
    ).encode(
        y=alt.Y('target:Q',axis=alt.Axis(title="",labels=False,ticks=False)),
        text=alt.Text('target:Q',format='1.0d')
    )

    txt_line = line.mark_text(align='center',
            baseline='middle',
            dy=-6, angle = 80, color = 'black'
    ).encode(
        text=alt.Text('Count of Merchants:Q',format='1.0d')
    )

    c = (bar + txt_bar+ line +txt_line).resolve_scale(y='independent').properties(width=650, height = 350, title = f"{col}")
    return c

# %%
cat1 = cat_alt('business_category')
cat2 = cat_alt('zone_name')
cat3 = cat_alt('manufacturer')

# %%
def num_alt(col):
    bins = [-.01,int(num_df[col].describe()['min']),int(num_df[col].describe()['25%']),int(num_df[col].describe()['50%']),\
           int(num_df[col].describe()['75%']),int(num_df[col].describe()['max'])]

    num_df[col]=pd.cut(x = num_df[col],bins = bins, duplicates = 'drop')
    df = (100*num_df.groupby(col)["target"].mean()).to_frame().reset_index()
    df[col] = df[col].astype('str')
    df['Count of Merchants'] = list(num_df.groupby(col)["merchant_id"].count())
    
    alt.themes.enable('fivethirtyeight')
    base = alt.Chart(df).encode(x=alt.X(f'{col}:O',axis=alt.Axis(title=""), sort = bins ))

    bar = base.mark_bar(color = 'lightgrey').encode(y=alt.Y('target:Q',axis=alt.Axis(title="Propensity %")))

    line =  base.mark_line(color='aqua').encode(
        y='Count of Merchants:Q'
    )
    txt_bar = bar.mark_text(align='center',
            baseline='middle',
            dy=-6
    ).encode(
        y=alt.Y('target:Q',axis=alt.Axis(title="",labels=False,ticks=False)),
        text=alt.Text('target:Q',format='.0f')
    )

    txt_line = line.mark_text(align='center',
            baseline='middle',
            dy=-6, angle = 80, color = 'black'
    ).encode(
        text=alt.Text('Count of Merchants:Q',format='.0f')
    )

    c = (bar + txt_bar+ line +txt_line).resolve_scale(y='independent').properties(width=170, height = 170, title = f"{col}")
    return c

# %%
num1 = num_alt('total_txn_count')
num2 = num_alt('m1_tpv')
num3 = num_alt('w1_sessions')
num4 = num_alt('total_atv')
num5 = num_alt('total_unique_payers')
num6 = num_alt('m1_atv')
num7 = num_alt('m1_max_daily_tpv')
num8 = num_alt('m1_active_days')
num8 = num_alt('total_active_vintage')

# %%
(num1|num2|num3|num4) & (num5|num6|num7|num8)
# Out:
# alt.VConcatChart(...)

# %%
col = geo
cat_df[col] = cat_df[col].astype('str')
top= list(cat_df[col].value_counts()[:50].index)
cat_df = cat_df[cat_df[col].isin(top)]
df = (100*cat_df.groupby(col)["target"].mean()).to_frame().reset_index()
df['Count of Merchants'] = list(cat_df.groupby(col)["merchant_id"].count())
df
alt.themes.enable('fivethirtyeight')
base = alt.Chart(df).encode(x=alt.X(f'{col}:N',axis=alt.Axis(title="") ))

bar = base.mark_bar(color = 'lightgrey').encode(y=alt.Y('target:Q',axis=alt.Axis(title="Propensity %")))

line =  base.mark_line(color='aqua').encode(
    y='Count of Merchants:Q'
)
txt_bar = bar.mark_text(align='center',
        baseline='middle',
        dy=-6
).encode(
    y=alt.Y('target:Q',axis=alt.Axis(title="",labels=False,ticks=False)),
    text=alt.Text('target:Q',format='1.0d')
)

txt_line = line.mark_text(align='center',
        baseline='middle',
        dy=-6, angle = 80, color = 'black'
).encode(
    text=alt.Text('Count of Merchants:Q',format='1.0d')
)

c = (bar + txt_bar+ line +txt_line).resolve_scale(y='independent').properties(width=650, height = 350, title = f"{col}")

# %%
cat1.properties(width = 900, height = 250)  & cat2.properties(width = 900, height = 250) & cat3.properties(width = 900, height = 250) & c.properties(width = 900, height = 250)
# Out:
# alt.VConcatChart(...)

# %%
 num_alt('vintage')
# Out:
# alt.LayerChart(...)
